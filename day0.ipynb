# %% [markdown]
# <a href="https://colab.research.google.com/github/KanhaiyaKumarShukla/ML-Practice/blob/main/day0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/pre-owned cars.csv")

# %%
df
# Out:
#          brand                                     model transmission  \
# 0     Mahindra              Thar LX D 4WD MT CONVERTIBLE       Manual
# 1      Hyundai                         Verna 1.6 VTVT SX       Manual
# 2         Tata  Harrier XT PLUS 2.0L KRYOTEC DARK EDITON       Manual
# 3        Honda                     City 1.5L I-VTE V CVT    Automatic
# 4         Ford             Ecosport TITANIUM 1.5L DIESEL       Manual
# ...        ...                                       ...          ...
# 2801      Ford           Ecosport TREND + 1.5L PETROL AT    Automatic
# 2802     Honda                        Jazz 1.2L I-VTEC V       Manual
# 2803   Hyundai                       Elite i20 MAGNA 1.2       Manual
# 2804    Maruti                   Baleno DELTA PETROL 1.2       Manual
# 2805       NaN                                       NaN          NaN
#
#       make_year    reg_year fuel_type  engine_capacity(CC)  km_driven  \
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d taweilo/taiwan-air-quality-data-20162024
# Out:
# Dataset URL: https://www.kaggle.com/datasets/taweilo/taiwan-air-quality-data-20162024
# License(s): CC0-1.0
# ...
#  99% 170M/172M [00:01<00:00, 128MB/s]
# 100% 172M/172M [00:01<00:00, 155MB/s]

# %%
import zipfile
zip_ref=zipfile.ZipFile('taiwan-air-quality-data-20162024.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()
